# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
df = pd.read_csv('/Users/phubetvani/Desktop/ml_lab1.csv')

# %%
df
# Out:
#      Unnamed: 0       Category  Age Sex   ALB    ALP    ALT    AST   BIL  \
# 0             1  0=Blood Donor   32   m  38.5   52.5    7.7   22.1   7.5
# 1             2  0=Blood Donor   32   m  38.5   70.3   18.0   24.7   3.9
# 2             3  0=Blood Donor   32   m  46.9   74.7   36.2   52.6   6.1
# 3             4  0=Blood Donor   32   m  43.2   52.0   30.6   22.6  18.9
# 4             5  0=Blood Donor   32   m  39.2   74.1   32.6   24.8   9.6
# ..          ...            ...  ...  ..   ...    ...    ...    ...   ...
# 610         611    3=Cirrhosis   62   f  32.0  416.6    5.9  110.3  50.0
# 611         612    3=Cirrhosis   64   f  24.0  102.8    2.9   44.4  20.0
# 612         613    3=Cirrhosis   64   f  29.0   87.3    3.5   99.0  48.0
# 613         614    3=Cirrhosis   46   f  33.0    NaN   39.0   62.0  20.0
# 614         615    3=Cirrhosis   59   f  36.0    NaN  100.0   80.0  12.0
#
#        CHE  CHOL   CREA    GGT  PROT
# 0     6.93  3.23  106.0   12.1  69.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         ALB         ALP         ALT         AST  \
# count  615.000000  615.000000  614.000000  597.000000  614.000000  615.000000
# mean   308.000000   47.408130   41.620195   68.283920   28.450814   34.786341
# std    177.679487   10.055105    5.780629   26.028315   25.469689   33.090690
# min      1.000000   19.000000   14.900000   11.300000    0.900000   10.600000
# 25%    154.500000   39.000000   38.800000   52.500000   16.400000   21.600000
# 50%    308.000000   47.000000   41.950000   66.200000   23.000000   25.900000
# 75%    461.500000   54.000000   45.200000   80.100000   33.075000   32.900000
# max    615.000000   77.000000   82.200000  416.600000  325.300000  324.000000
#
#               BIL         CHE        CHOL         CREA         GGT        PROT
# count  615.000000  615.000000  605.000000   615.000000  615.000000  614.000000
# mean    11.396748    8.196634    5.368099    81.287805   39.533171   72.044137
# ...

# %%
# TWO METHOD OF EDA FOR NUMERIC DATA ATTRIBUTE
#define size of plot sheet 
plt.figure(figsize=(16,8)) 
#create swarmplot v
ax = sns.swarmplot(x="Age", y="PROT", data=df)

# %%
plt.figure(figsize=(16, 8))
plt.title("COUNTPLOT FOR AGE")
#plot histogram based on age
sns.countplot(data = df, x = 'Age')
# Out:
# <AxesSubplot:title={'center':'COUNTPLOT FOR AGE'}, xlabel='Age', ylabel='count'>

# %%
# TWO METHOD OF EDA FOR NOMINAL DATA ATTRIUTE 
plt.figure(figsize=(16,8))
plt.title("CHOL FOR EACH CATEGORY")
sns.boxplot(x='Category',y='CHOL',data=df)
# Out:
# <AxesSubplot:title={'center':'CHOL FOR EACH CATEGORY'}, xlabel='Category', ylabel='CHOL'>

# %%
df.groupby(["Category", "Sex"]).count()
# Out:
#                             Unnamed: 0  Age  ALB  ALP  ALT  AST  BIL  CHE  \
# Category               Sex
# 0=Blood Donor          f           215  215  215  215  215  215  215  215
#                        m           318  318  318  318  318  318  318  318
# 0s=suspect Blood Donor f             1    1    1    1    1    1    1    1
#                        m             6    6    6    6    6    6    6    6
# 1=Hepatitis            f             4    4    4    4    4    4    4    4
#                        m            20   20   20   17   19   20   20   20
# 2=Fibrosis             f             8    8    8    4    8    8    8    8
#                        m            13   13   13    8   13   13   13   13
# 3=Cirrhosis            f            10   10   10    8   10   10   10   10
#                        m            20   20   19   16   20   20   20   20
#
#                             CHOL  CREA  GGT  PROT
# Category               Sex
# ...

# %%
# BOX PLOT
plt.figure(figsize=(16,8))
sns.boxplot(x='Age', y='PROT', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='PROT'>

# %%
# BAR GRAPH
df['Sex'].value_counts().plot(kind='bar')
plt.xlabel("Gender")
plt.ylabel("Frequency");

# %%
# HISTOGRAM
chm= df[df['Sex']=='m']['CHOL']

plt.figure(figsize=(16,8))
plt.title("MALE")
plt.hist(df[df['Sex']=='m']['CHOL'])
plt.xlabel('CHOL')
plt.ylabel('Number of PEOPLE')
plt.grid()
plt.show()

# %%
# HISTOGRAM
chf= df[df['Sex']=='f']['CHOL']
plt.figure(figsize=(16,8))
plt.title("FEMALE")
plt.hist(df[df['Sex']=='f']['CHOL'])
plt.xlabel('CHOL')
plt.ylabel('Number of PEOPLE')
plt.grid()
plt.show()

# %%
# SCATTER PLOT
plt.figure(figsize=(16,8))
plt.title("AGE vs CHOL")
plt.scatter(df['Age'],df['CHOL'])
plt.xlabel('Age')
plt.ylabel('CHOL')
plt.legend(loc='lower right')
# Out:
# No handles with labels found to put in legend.

# %%
# SWAM PLOT
plt.figure(figsize=(16,8))
ax = sns.swarmplot(x="Sex", y="CHOL", data=df)

# %%
# REG PLOT
plt.figure(figsize=(16,8))
plt.title("AGE vs PROT")
sns.regplot(x='Age',y='PROT',data=df)
# Out:
# <AxesSubplot:title={'center':'AGE vs PROT'}, xlabel='Age', ylabel='PROT'>

# %%
# VIOLIN PLOT
plt.figure(figsize=(16,8))
ax = sns.violinplot(x="Sex", y="PROT", data=df)
